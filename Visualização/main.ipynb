# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_style("whitegrid")

# %%
df = pd.read_csv("winequalityN.csv")

# %%
sns.barplot(x = df.type.value_counts().index,
y = df.type.value_counts().values,
data=df)
# Out:
# <AxesSubplot: >

# %%
fig = plt.figure(figsize=(7, 4))
sns.barplot(x = df.type.value_counts().index,
y = df.type.value_counts().values,
data=df,
palette={"white":"#F5F5F5"
,
"red":"#5e2129"},
edgecolor='gray'
,
linewidth=1,
)
plt.title("Quantidade de vinhos por tipo"
,fontsize=14,fontweight='bold')
plt.xlabel("Tipo"
,fontsize=14,fontweight='bold')
plt.ylabel("Quantidade"
,fontsize=14,fontweight='bold')
plt.xticks([0,1],["Branco"
,
"Tinto"])
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()
fig.savefig("barra2.png"
, dpi=fig.dpi,bbox_inches='tight')

# %%
g = sns.scatterplot(data=df,
x="alcohol"
,
y="total sulfur dioxide"
,
hue="type"
,
palette={"white":"#F5F5F5"
,
"red":"#5e2129"})

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
len(df)
# Out:
# 6497

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
sns.lineplot(x='pH'
, y='quality'
, hue="type"
,
style="type"
, markers = ["o"
,
"d"],
palette={"white":"#F5F5F5"
,
"red":"#5e2129"},
dashes=False, ci=None, data=df)
# Out:
# C:\Users\Miguel\AppData\Local\Temp\ipykernel_17484\2963599914.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='pH'
# <AxesSubplot: xlabel='pH', ylabel='quality'>

# %%
sns.lineplot(x='pH'
, y='quality'
, hue="type"
,
style="type"
, markers = ["o"
,
"d"],
palette={"white":"gray"
,
"red":"#5e2129"},
dashes=False, ci=None, data=df)
# Out:
# C:\Users\Miguel\AppData\Local\Temp\ipykernel_17484\4178348192.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='pH'
# <AxesSubplot: xlabel='pH', ylabel='quality'>

# %%
fig = plt.figure(figsize=(7, 4))
sns.barplot(x = df[df.pH > 3.21].type.value_counts().index, 
            y = df[df.pH > 3.21].type.value_counts().values, 
            data=df[df.pH > 3.21], 
            palette={"white":"#F5F5F5", "red":"#5e2129"}, 
            edgecolor='gray', 
            linewidth=3)
# Out:
# <AxesSubplot: >
